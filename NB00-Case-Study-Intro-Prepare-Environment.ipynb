# %% [markdown]
# **IMPORTANT:** If you are running this notebook for the first time, please run the first code cell below by pressing Shift-Enter while in it. If not, please skip it. This digital case study has been developed for Jupyter Notebook Python 3 kernel.

# %%
# %run resources/library.py
style_notebook()
# Out:
# <style>
# div.text_cell_render { /* Customize text cells */
#     font-family: 'Arial';
#     font-size:20px;
#     line-height: 1.5em;
#     padding-left:3em;
#     padding-right:3em;
# }
# .CodeMirror {
#     font-family:  'Source Code Pro', monospace;
#     font-size: 18px;
# }
#
# /* Cell output */
#
# .rendered_html pre, .rendered_html code {
#     color: inherit !important;
#     background-color: inherit !important;
# }
# div.output_area pre {
#     line-height: 1.2em;
#     color: #93a1a1 !important;
#     font-family: 'Source Code Pro', monospace;
#     font-size: 16px;
# }
# .rendered_html table, .rendered_html td, .rendered_html th {
#     border: 1px solid #586e75 !important;
#     font-family: 'Arial';
#     font-size: 16px;
# }
# </style>

# %% [markdown]
# # Set up Python Packages for Case Study INTRO

# %% [markdown]
# *Version 1.0.0 Created by Herman Tolentino, MD, 6 September 2018*

# %% [markdown]
# We need to set up the following Python software packages that are not installed in the Microsoft Azure Jupyter Notebooks server:
#
# * For record linkage
#   * Folium: web mapping library

# %% [markdown]
# The `bash` scripts below will install the above packages if they are not yet installed. You can run all cells for this notebook to install these packages if not yet installed (see below).

# %% [markdown]
# <img src='data:image/png;base64,...' width='400'>

# %% [markdown]
# You can learn more about `bash` scripting [here](http://matt.might.net/articles/bash-by-example/). The `%%bash` directive at the top of each code cell simulates a `bash` shell.

# %%
# %%bash
# bash resources/setup.sh

# %% [markdown]
# ## References

# %% [markdown]
# 1. Might, Matt. Shell programming with bash: by example, by counter-example. URL: http://matt.might.net/articles/bash-by-example/.
